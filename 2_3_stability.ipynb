% %%
clear all

% %% [markdown]
% #### 2.3 Stability and LFT

% %% [markdown]
% 2.3.1 Stability and LFT
%
% ![image.png](attachment:image.png)
%
% ![image-2.png](attachment:image-2.png)

% %%
m = ureal('m', 10, "Percentage", [-50 80]);
c = ureal('c', 10, "Percentage", [-40 40]);
k = ureal('k', 1, "Percentage", [-20 80]);
h = ureal('h', 2.5, "Percentage", [-20 80]);

A = [0 1;
    -k/m -c/m];
B = [0;1/m];
C = [h 0];
sys = ss(A,B,C,0);

% %% [markdown]
% ![image.png](attachment:image.png)
